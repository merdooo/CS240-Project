# %%
from __future__ import print_function, division
# %matplotlib inline
import pandas as pd
import numpy as np
import thinkstats2
import thinkplot

# %%
mydata=pd.read_csv("Pitching.csv")
mydata.head(50)
# Out:
#      playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...   IBB  WP  \
# 0   bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...   NaN NaN
# 1   brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...   NaN NaN
# 2   fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...   NaN NaN
# 3   fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...   NaN NaN
# 4   fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...   NaN NaN
# 5   flowedi01    1871      1    TRO  NaN   0   0   1   0   0  ...   NaN NaN
# 6    mackde01    1871      1    RC1  NaN   0   1   3   1   1  ...   NaN NaN
# 7   mathebo01    1871      1    FW1  NaN   6  11  19  19  19  ...   NaN NaN
# 8   mcbridi01    1871      1    PH1  NaN  18   5  25  25  25  ...   NaN NaN
# 9   mcmuljo01    1871      1    TRO  NaN  12  15  29  29  28  ...   NaN NaN
# 10  meyerle01    1871      1    PH1  NaN   0   0   1   0   0  ...   NaN NaN
# ...

# %%
mystats = mydata.loc[:,['playerID', 'W', 'L']]
mystats
# Out:
#         playerID   W   L
# 0      bechtge01   1   2
# 1      brainas01  12  15
# 2      fergubo01   0   0
# 3      fishech01   4  16
# 4      fleetfr01   0   1
# 5      flowedi01   0   0
# 6       mackde01   0   1
# 7      mathebo01   6  11
# 8      mcbridi01  18   5
# 9      mcmuljo01  12  15
# 10     meyerle01   0   0
# 11     paborch01   0   2
# 12     pinkhed01   1   0
# 13     prattal01  10  17
# 14     spaldal01  19  10
# 15     stearbi01   2   0
# 16     woltery01  16  16
# 17     wrighha01   1   0
# 18     zettlge01  18   9
# 19     bentlcy01   2  15
# 20     brainas01   2   7
# 21     brainas01   0   2
# 22     brittji01   9  28
# 23     buttefr01   3   2
# 24     cummica01  33  20
# 25     fishech01  10   1
# 26     malonma01   0   3
# 27     martiph01   1   2
# 28     martiph01   2   7
# 29     mathebo01  25  18
# ...          ...  ..  ..
# 44933  wilheto01   2   3
# 44934  wilheto01   0   1
# 44935  willije02   0   0
# 44936  willitr01   1   1
# 44937  wilsoal01   4   0
# ...

# %%
mystats.describe()
# Out:
#                   W             L
# count  44963.000000  44963.000000
# mean       4.715744      4.715722
# std        5.813410      4.988846
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        2.000000      3.000000
# 75%        7.000000      8.000000
# max       59.000000     48.000000

# %%
histogram = thinkstats2.Hist(mystats.W, label='Winning')
thinkplot.Hist(histogram)
thinkplot.Config(xlabel='Winnig', ylabel='Count',loc='upper right')

# %%
histogram2 = thinkstats2.Hist(mystats.L, label='Lossing')
thinkplot.Hist(histogram2)
thinkplot.Config(xlabel='Lossing', ylabel='Count',loc='upper right')

# %%
n = histogram.Total()
pmf = histogram.Copy()
for x, freq in histogram.Items():
    histogram[x] = freq / n

histogram
# Out:
# Hist({0: 0.27967439895024798, 1: 0.13566710406334098, 2: 0.092320352289660387, 3: 0.069612792740697912, 4: 0.059181994084024643, 5: 0.047394524386717971, 6: 0.040032915953117004, 7: 0.034628472299446211, 8: 0.029713319840757958, 9: 0.028556813379890134, 10: 0.024953850944109603, 11: 0.023841825500967462, 12: 0.020772635277895159, 13: 0.018793229989102149, 14: 0.017458799457331583, 15: 0.014767697884927607, 16: 0.012588128016369014, 17: 0.0091408491426283826, 18: 0.0083401908235660425, 19: 0.0060716589195560795, 20: 0.0062718234993216649, 21: 0.0044258612637057132, 22: 0.0031803927673865178, 23: 0.0024909369926383916, 24: 0.0017125191824388943, 25: 0.0016235571469875231, 26: 0.0011120254431421391, 27: 0.0010008228988279252, 28: 0.00075617730133665454, 29: 0.00048929119498254117, 30: 0.00051153170384538396, 31: 0.00042256966839401285, 32: 0.00017792407090274227, 33: 0.00040032915953117006, 34: 0.00028912661521695616, 35: 0.00026688610635411337, 36: 0.00020016457976558503, 37: 0.0001334
# ...

# %%
runs_pmf = thinkstats2.Pmf(histogram, label='Lossing')
hits_pmf = thinkstats2.Pmf(histogram2, label='Winnig')
thinkplot.Hist(runs_pmf)
thinkplot.Config(xlabel='Lossing', ylabel='Pmf')

# %%
thinkplot.Hist(hits_pmf)
thinkplot.Config(xlabel='Winning', ylabel='Pmf')

# %%
lossing_cdf = thinkstats2.Cdf(mystats.L, label='lossing')
thinkplot.Cdf(lossing_cdf)
thinkplot.Config(xlabel='Lossing', ylabel='CDF', loc='upper left')

# %%
winning_cdf = thinkstats2.Cdf(mystats.W, label='winning')
thinkplot.Cdf(winning_cdf)
thinkplot.Config(xlabel='Winning', ylabel='CDF', loc='upper left')

# %%
thinkplot.PrePlot(1)
for lam in [2.0,1,0.5]:
    xs, ps = thinkstats2.RenderExpoCdf(lam,mystats.L.min(), mystats.L.max())
    label = r'$\lambda=%g$' % lam
    thinkplot.Plot(xs, ps, label=label)
    
thinkplot.Config(title='Exponential CDF', xlabel='Lossing', ylabel='CDF', 
                 loc='lower right')
# Out:
# thinkplot.py:118: UserWarning: Ran out of colors.  Starting over.

# %%
thinkplot.PrePlot(1)
for lam in [2.0,1,0.5]:
    xs, ps = thinkstats2.RenderExpoCdf(lam,mystats.W.min(), mystats.W.max())
    label = r'$\lambda=%g$' % lam
    thinkplot.Plot(xs, ps, label=label)
    
thinkplot.Config(title='Exponential CDF', xlabel='Winning', ylabel='CDF', 
                 loc='lower right')

# %%
class HypothesisTest(object):

    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)

    def PValue(self, iters=2000):
        self.test_stats = [self.TestStatistic(self.RunModel()) 
                           for _ in range(iters)]

        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters

    def TestStatistic(self, data):
        raise UnimplementedMethodException()

    def MakeModel(self):
        pass

    def RunModel(self):
        raise UnimplementedMethodException()

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        mystats.L, mystats.W = data
        test_stat = abs(mystats.W.std() - mystats.L.std())
        return test_stat

    def MakeModel(self):
        mystats.L, mystats.W = self.data
        self.n, self.m = len(mystats.L), len(mystats.W)
        self.pool = np.hstack((mystats.L, mystats.W))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
data = mystats.L, mystats.W
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.789

# %%
class CorrelationPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        xs, ys = data
        test_stat = abs(thinkstats2.Corr(xs, ys))
        return test_stat

    def RunModel(self):
        xs, ys = self.data
        xs = np.random.permutation(xs)
        return xs, ys

# %%
data = mystats.L, mystats.W
correlationtest = CorrelationPermute(data)
pvalue = correlationtest.PValue()
pvalue
# Out:
# 0.663
